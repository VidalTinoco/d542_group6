# %%
import pandas as pd
import numpy as np
import re
import spacy

# %% [markdown]
# ### Cleaning

# %%
df = pd.read_csv('NL_code_difference_clean.csv', na_values=['', 'nan'])

def clean_df(df, filter_state=False, state="CLOSED", merged=False):
    df = df.drop_duplicates(subset=['Prompt'], keep='first')
    
    # Replace newlines with empty space and strip
    df.loc[:, 'difference'] = df['difference'].str.replace(r'\n+', ' ', regex=True).str.strip()

    # Drop rows where 'difference' is an empty string (indicates prompt was just code)
    df = df[df['difference'].notna() & (df['difference'] != '')]

    # Remove URLs and file paths
    df.loc[:, 'difference'] = df['difference'].apply(lambda text: re.sub(r'http\S+|www\S+|https\S+', '', text))
    df.loc[:, 'difference'] = df['difference'].apply(lambda text: re.sub(r'[a-zA-Z]:\\[\\\S|*\S]?.*|/\S+', '', text))

    if filter_state:
        df = df[df['State'] == state].reset_index(drop=True)

    if merged:
        df = df.groupby('conversation_id').agg({
            'difference': lambda x: ' '.join(x.dropna().astype(str)) if not x.dropna().empty else None,  # avoid empty groups
            'State': 'first',       # keep first value of State (same for all prompts in a conversation)
            'numPrompts': 'first',  # keep first value of numPrompts
        }).reset_index()

    return df

# %%
df_full = clean_df(df)
df_open = clean_df(df, True, "OPEN")
df_closed = clean_df(df, True)
df_merged = clean_df(df, merged=True)
df_closed_merged = clean_df(df, True, True)

# %% [markdown]
# ### Functions

# %%
# Load SpaCy model
nlp = spacy.load('en_core_web_sm')

# 'it', 'is', 'in', 'for', 'do', 'does', 'did'
words_to_remove = ['what', 'how', 'why', 'when', 'where', 'which', 'if', 'can', 'could', 'would', 'should', 'must',
                   'explain', 'show', 'tell', 'help', 'write', 'make', 'create', 'see', 'are', 'was', 'were', 
                   'using', 'this', 'that', 'mean', 'means', 'need', 'want', 
                   'have', 'give', 'get', 'please', 'no', 'not', 'only', 'many', 'all']

for word in words_to_remove:
    if word in nlp.Defaults.stop_words: 
        nlp.Defaults.stop_words.remove(word)
        nlp.vocab[word].is_stop = False

words_to_add = ['i', 'you', 'be', 'this', 'that', 'it', 'in', 'for', 'do', 'does', 'did']
for word in words_to_add:
    nlp.vocab[word].is_stop = True

def custom_tokenizer(text):
    # Remove common code terms
    code_terms = {
        'github', 'com', 'http', 'https', 'localhost', 'api',
        'json', 'xml', 'html', 'css', 'js', 'php', 'sql',
        'readme', 'md', 'txt', 'pdf', 'doc', 'docx'
    }

    # Process the text with SpaCy (convert to lowercase before processing)
    doc = nlp(text.lower())
    
    # Define allowed POS tags
    allowed_pos = {"ADJ", "NOUN", "VERB", "AUX", "PRON", "ADV", 
                   "DET", "SCONJ", "INTJ", "ADP", "PART"}

    # Filter tokens once and extract both lemmas and POS tags
    filtered_tokens = [(token.lemma_, token.pos_) for token in doc 
                       if token.is_alpha
                       and not token.is_space
                       and not token.is_punct
                       and not token.is_stop
                       and token.text not in code_terms
                       and token.pos_ in allowed_pos]

    # Extract lemmas and POS tags separately
    tokens = [lemma for lemma, _ in filtered_tokens]
    pos_tags = [pos for _, pos in filtered_tokens]
    
    return tokens, pos_tags

def count_pos(tags):
    """Extract position tags as features."""
    pos_features = dict.fromkeys(["ADJ", "NOUN", "VERB", "AUX", "PRON", "ADV", "DET", "SCONJ", "INTJ", "ADP", "PART"], 0)
    
    for tag in tags:
        if tag in pos_features:
            pos_features[tag] += 1
    
    return list(pos_features.values())

def get_tokenized(df):
    raw_tokens = []
    tokenized_data = []
    pos_data = []
    
    for text in df['difference']:
        tokens, pos_tags = custom_tokenizer(text)
        raw_tokens.append(tokens)
        tokenized_data.append(" ".join(tokens)) # ?
        pos_data.append(count_pos(pos_tags))

    return raw_tokens, tokenized_data, pos_data

# %% [markdown]
# ### embeddings

# %%
import torch
from transformers import BertTokenizer, BertModel

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

def get_embeddings(tokenized_data):
    embeddings = []
    for tokens in tokenized_data:
    # for text in df['difference']: # performed worse when text was not tokenized
        inputs = tokenizer(" ".join(tokens), return_tensors="pt", padding=True, truncation=True)
        with torch.no_grad():
            outputs = model(**inputs)
        cls_embedding = outputs.last_hidden_state[0][0].numpy()
        embeddings.append(cls_embedding)
    
    embeddings = np.array(embeddings)
    
    return embeddings

# %%
raw_tokens, tokenized_data, pos_data = get_tokenized(df_closed)
embeddings = get_embeddings(tokenized_data)

# add to df
df_closed['raw_tokens'] = raw_tokens
print('done')
# Out:
# done

# %%
kmeans = get_kmeans(df_closed, embeddings, k=7 ,show_samples=True) # i do not think the embeddings are good... but it generates more balanced clusters than tf-idf :(
# Out:
# cluster
# 2    81
# 6    73
# 3    69
# 1    47
# 5    42
# 4    22
# 0    12
# Name: count, dtype: int64
# Cluster 0:
#   - code how update librecalc file change formatting cell
#   - how could create use separate proj context worker thread specific ogrcoordinatetransformation use gdal
#   - example book chapter lesson how can get implementation business logic model avoid use service model
#   - method forward implement exist class ehre class extend llamapretrainedmodel
#   - person child age birthday like educational toy find gift interesting fun thoughtful
#   - nevermind let leave verification type string think benefit have separate model
#   - how implement client client protocol
#   - provide follow openapi specification please show how could make request ti download url
#   - work showing level weird should show info instead level
#   - need help help kind symlink laravel app have number video be upload storage folder understanding able access file url can help
# Cluster 1:
# ...

# %% [markdown]
# ### tf-idf

# %%
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidf_vectorize(tokenized_data, ngram_range=(1,2), max_features=100, min_df=0.01, max_df=0.7):
    vectorizer = TfidfVectorizer(
        ngram_range=ngram_range,  # Capture 2-4 word phrases
        max_features=max_features,    # Best performance usually
        min_df=min_df,         # Remove terms that appear in less than 1% of documents
        max_df=max_df,          # Remove terms that appear in more than 70% of documents
        stop_words=list(nlp.Defaults.stop_words) # Default stopwords
    )

    # Transform the tokenized text data into TF-IDF features
    tf_idf = vectorizer.fit_transform(tokenized_data)
    return tf_idf, vectorizer

# %%
import random
from sklearn.cluster import KMeans

def get_kmeans(df, features, k=5, show_samples=False, sample_size=10):
    # e.g. features = embeddings
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(features)
    
    df['cluster'] = kmeans.predict(features)
    print(df['cluster'].value_counts())

    if show_samples:
        for i in range(k):
            print(f"Cluster {i}:")
            
            # Get indices where cluster == i
            cluster_indices = df[df['cluster'] == i].index.tolist()
            
            # Sample min(sample_size, available indices) to avoid errors
            sampled_indices = random.sample(cluster_indices, min(sample_size, len(cluster_indices)))

            # Print tokenized data for the sampled indices
            for idx in sampled_indices:
                print(f"  - {tokenized_data[idx]}")
            
            print('=' * 50)
            print('\n')

    return kmeans # return fit model

def get_top_words(tfidf_vectorizer, kmeans, n_words):
    # Get top words for each cluster
    feature_names = tfidf_vectorizer.get_feature_names_out()
    cluster_centers = kmeans.cluster_centers_
    
    # Store top words for each cluster
    top_words_per_cluster = {}
    n_top_words = n_words
    
    # Loop over each cluster center
    for i in range(kmeans.n_clusters):
        # Get the center vector for the current cluster
        center_vector = cluster_centers[i]
        
        # Get the indices of the top words based on the highest TF-IDF values
        top_indices = center_vector.argsort()[-n_top_words:][::-1]
        
        # Map the top indices to the corresponding feature names (words)
        top_words = [feature_names[idx] for idx in top_indices]
        
        # Store the top words for the current cluster
        top_words_per_cluster[i] = top_words
    
    # Print the top words for each cluster
    for i, words in top_words_per_cluster.items():
        print(f"Cluster {i}: {', '.join(words)}")

# %%
tf_idf, vectorizer = tfidf_vectorize(tokenized_data, (1, 3), 1000, 0.02)
print(tf_idf.shape[1])
# Out:
# 139
# /Users/janeshen/.pyenv/versions/3.11.10/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   warnings.warn(

# %%
kmeans = get_kmeans(df_closed, tf_idf, 4, show_samples=True)
# Out:
# cluster
# 0    159
# 1     97
# 2     58
# 3     32
# Name: count, dtype: int64
# Cluster 0:
#   - teste
#   - reject stable stable refuse allow app create update workflow workflow permission can write avoid error
#   - ok fine if go allow short code link could use short code see issue thing way provide include email link maybe link could like
#   - oh know problem not exit anymore completion good let try way fix code
#   - give post lot word
#   - correct answer option b rewrite explanation
#   - follow documentation
#   - oh sorry mess paste code try
#   - code execute monacoeditor ts monacoeditor see no type when import axios ts datum newlink const axios await axios axios instal
#   - please propose cloned augmented source file initiate check rpc switch available binary path initialization code corersponding wiring replacement code access
# ...
#
#
# Cluster 1:
#   - how docker build
# ...

# %%
get_top_words(vectorizer, kmeans, 20)
# Out:
# Cluster 0: code, can, text, error, need, not, return, please, run, no, list, like, ok, have, try, give, work, way, write, create
# Cluster 1: use, how, can, would, which, could, how can, should, create, show, if, user, have, not, get, write, number, make, instead, type
# Cluster 2: want, file, if, use, have, step, what, authentication, can, database, like, how, open, user, post, function, option, give, repo, action
# Cluster 3: what, have, like, type, kind, option, would, use, look, please, error, database, datum, mean, possible, example, new, server, could, response

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Count occurrences of each state per cluster
# df_counts = df_closed.groupby(['cluster', 'State']).size().reset_index(name='count')

# # Create FacetGrid to facet by cluster
# g = sns.FacetGrid(df_counts, col='cluster', col_wrap=2, sharey=True, height=4)
# g.map_dataframe(sns.barplot, x='State', y='count', hue='State', palette='viridis', legend=False)

# # Adjust labels
# g.set_axis_labels("State", "Count")
# g.set_titles("Cluster {col_name}")

# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

def plot_word_counts(df, target_words):
    """
    Plots the mean normalized counts of target words across clusters.

    Parameters:
        df (pd.DataFrame): DataFrame containing the cluster assignments and tokenized data.
        target_words (list): List of words to count.
        cluster_column (str): Column name representing cluster labels.
    """
    # Compute mean normalized counts per cluster
    df_grouped = df.groupby('cluster')[target_words].mean().reset_index()
    df_melted = df_grouped.melt(id_vars=cluster_column, var_name='Word', value_name='Mean Normalized Count')

    # Plot the results
    g = sns.FacetGrid(df_melted, col='cluster', col_wrap=2, sharey=True)
    g.map_dataframe(sns.barplot, x="Word", y="Mean Normalized Count", hue="Word", palette="tab10", dodge=False)

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=45)
        ax.grid(True, which='both', axis='both', linestyle='-', linewidth=0.7, color='lightgray')  # Adding grid lines

        # Ensure bars are above the grid
        for bar in ax.patches:
            bar.set_zorder(10)

    plt.legend([], [], frameon=False)
    plt.show()

def plot_pos_features(df, feature_columns):
    """
    Plots the mean of position tag features across clusters using a faceted bar plot.

    Parameters:
        df (pd.DataFrame): DataFrame containing the cluster assignments and position tag features.
        feature_columns (list): List of position tag feature column names.
        cluster_column (str): Column name representing cluster labels.
    """
    df_grouped = df.groupby('cluster')[feature_columns].mean().reset_index()
    df_melted = df_grouped.melt(id_vars='cluster', var_name='Feature', value_name='Mean Value')

    g = sns.FacetGrid(df_melted, col='cluster', col_wrap=2, sharey=True)
    g.map_dataframe(sns.barplot, x="Feature", y="Mean Value", hue="Feature", palette="tab10", dodge=False)

    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=45)
        ax.grid(True, which='both', axis='both', linestyle='-', linewidth=0.7, color='lightgray')  # Adding grid lines

        # Adjust bars' zorder to ensure they are above the grid
        for bar in ax.patches:
            bar.set_zorder(10)

    plt.legend([],[], frameon=False)
    plt.show()

def transform_word_count(df, target_words):
    # Count occurrences of each target word
    for word in target_words:
        df[word] = df['raw_tokens'].apply(lambda tokens: tokens.count(word))

    # Normalize the word counts for each cluster
    scaler = MinMaxScaler()

    # Normalize each target word's count across the entire dataset
    for word in target_words:
        word_counts = df[word].values.reshape(-1, 1)
        normalized_word_counts = scaler.fit_transform(word_counts).flatten()

        # Ensure the target column is of type float before assigning the normalized values
        df[word] = df[word].astype(float)

        # Assign the normalized values back to the dataframe
        df[word] = normalized_word_counts

    return df

def transform_pos(pos_data):
    # Convert dependency features to DataFrame and normalize
    scaler = MinMaxScaler()
    normalized_features = scaler.fit_transform(np.array(pos_data))
    
    labels = ["ADJ", "NOUN", "VERB", "AUX", "PRON", "ADV", "DET", "SCONJ", "INTJ", "ADP", "PART"]
    pos_df = pd.DataFrame(normalized_features, columns=labels)

    return pos_df

# %%
# get normalized features dataframe
pos_df = transform_pos(pos_data)

# combine with original DataFrame
df_combined = pd.concat([df_closed, pos_df], axis=1)

# Plot the dependency features per cluster
feature_names = ["ADJ", "NOUN", "VERB", "AUX", "PRON", "ADV", "DET", "SCONJ", "INTJ", "ADP", "PART"]
plot_pos_features(df_combined, feature_names)

# %%
pos_temp = pd.DataFrame(pos_data, columns=feature_names)
pos_temp[feature_names].boxplot()
# Out:
# <Axes: >

# %%
tokenized_data, pos_data = get_tokenized(df_open)
pos_df = transform_pos(pos_data)

feature_means = pos_df[feature_names].mean().reset_index()
feature_means.columns = ['Feature', 'Mean']

plt.figure(figsize=(3, 3))
ax = sns.barplot(data=feature_means, x="Feature", y="Mean", hue="Feature", palette="tab10")
ax.set_ylim(0, 0.12)

ax.grid(True, which='both', axis='both', linestyle='-', linewidth=0.7, color='lightgray')  # Adding grid lines
for bar in ax.patches:
    bar.set_zorder(10)
    
plt.xticks(rotation=45)
plt.xlabel("Dependency Feature")
plt.ylabel("Total Count")
plt.title("Total Counts of Dependency Features")
plt.show()

# %%
target_words = ["what", "which", "how", "can", "would", "should", "could", "code", "error", "option"]

df = transform_word_count(df_closed, target_words)
df.describe()

plot_pos_features(df, target_words)

# %%
raw_tokens, tokenized_data, pos_data = get_tokenized(df_open)

# add to df
df_open['raw_tokens'] = raw_tokens
df_open = transform_word_count(df_open, target_words)

# Compute mean of each feature across the entire dataset
mean_values = df_open[target_words].mean().reset_index()
mean_values.columns = ['Feature', 'Mean Value']

# Create figure
plt.figure(figsize=(3,3))
ax = sns.barplot(data=mean_values, x="Feature", y="Mean Value", hue="Feature", palette="tab10")

# Formatting
plt.xticks(rotation=45)
plt.grid(True, which='both', axis='both', linestyle='-', linewidth=0.7, color='lightgray')
plt.title("Mean of Position Tag Features Across Dataset")

# Ensure bars are above the grid
for bar in ax.patches:
    bar.set_zorder(10)

plt.show()

# %%
df_closed['numPrompts'].hist()
# Out:
# <Axes: >

# %%
df_open['numPrompts'].hist()
# Out:
# <Axes: >

# %%
# Combine TF-IDF features with normalized dependency features (concatenate)
X_combined = np.hstack([X_tfidf.toarray(), dep_features_normalized])
print(X_combined.shape[1])
# Out:
# 30

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.5, min_samples=2, metric='cosine')
df['cluster'] = dbscan.fit_predict(matrix)

df['cluster'].value_counts()
# Out:
# cluster
#  0    63
# -1    53
# Name: count, dtype: int64

# %%
# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Get the DBSCAN cluster labels
labels = dbscan.labels_

# Initialize a dictionary to store the top words for each cluster
top_words_per_cluster = {}

# Loop over each unique cluster label (excluding noise points labeled as -1)
for label in set(labels):
    if label == -1:  # Skip noise points
        continue

    # Get the indices of the documents in the current cluster
    cluster_indices = [i for i, lbl in enumerate(labels) if lbl == label]
    
    # Extract the corresponding TF-IDF values for the documents in the current cluster
    cluster_tfidf = X_tfidf[cluster_indices]
    
    # Sum the TF-IDF values for each term in the cluster
    cluster_sum = cluster_tfidf.sum(axis=0).A1  # Convert sparse matrix to dense array (A1)
    
    # Get the indices of the top words (based on summed TF-IDF values)
    top_indices = cluster_sum.argsort()[-10:][::-1]  # Get the top 10 words
    
    # Map the top indices to the corresponding feature names (words)
    top_words = [feature_names[idx] for idx in top_indices]
    
    # Store the top words for the current cluster
    top_words_per_cluster[label] = top_words

# Print the top words for each cluster
for label, words in top_words_per_cluster.items():
    print(f"Cluster {label}: {', '.join(words)}")
# Out:
# Cluster 0: can you, do this, how can, how do, what do, do you, could you, that it, do it, that can
